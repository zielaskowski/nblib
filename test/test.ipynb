% %%
# outside markdown levels: ignore
1+1
% Out:
% ans = 2

% %% [markdown]
% # level 1
% this is first level

% %% [markdown]
% just markdown

% %% [markdown]
% ## level2
% some text

% %% [markdown]
% ### level3
% some other text

% %%
#code
2+2
% Out:
% ans = 4
% ERROR: received bad message: No such comm registered: 3c08cd7c-477e-4ae4-9f2b-114ebbaddd07
% Message type: comm_msg
% ERROR: received bad message: No such comm registered: e4b5b4da-82da-4d5e-9851-17bb3821e4a4
% Message type: comm_msg
% ERROR: received bad message: No such comm registered: fe189fb8-16b5-413e-adeb-3026e0bb4dac
% Message type: comm_msg
% ERROR: received bad message: No such comm registered: f7fa60ec-99ee-4dac-8f12-7a41191cbc81
% Message type: comm_msg
% ERROR: received bad message: No such comm registered: cb9b15d3-6e6d-4d94-a806-a22f04abc2ab
% Message type: comm_msg

% %% [markdown]
% markdown after code

% %% [markdown]
% # level11
% another level 1

% %% [markdown]
% ## level22
% another level 2

% %% [markdown]
% ## level2
% some text

% %%
## level2
some text
